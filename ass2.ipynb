# %%
student = {"name": "Khushal","age": 20,"course": "CSE"}
print("Dictionary:")
print(student)
print(student["name"])
student["city"] = "Jaipur"
print(student)
# Out:
# Dictionary:
# {'name': 'Khushal', 'age': 20, 'course': 'CSE'}
# Khushal
# {'name': 'Khushal', 'age': 20, 'course': 'CSE', 'city': 'Jaipur'}

# %%
fruits = ("apple", "banana", "mango")
print("Tuple:")
print(fruits)
print(fruits[0])
# Out:
# Tuple:
# ('apple', 'banana', 'mango')
# apple

# %%
numbers = {1, 2, 3, 4, 4, 5}
print("Set:")
print(numbers)
numbers.add(6)
print("After adding 6:")
print(numbers)
# Out:
# Set:
# {1, 2, 3, 4, 5}
# After adding 6:
# {1, 2, 3, 4, 5, 6}

# %%
def add(a, b):
    return a + b
def subtract(a, b):
    return a - b
def multiply(a, b):
    return a * b
def divide(a, b):
    if b == 0:
        return "Error: Division by zero is not allowed."
    else:
        return a / b
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
print("Addition =", add(num1, num2))
print("Subtraction =", subtract(num1, num2))
print("Multiplication =", multiply(num1, num2))
print("Division =", divide(num1, num2))
# Out:
# Addition = 26
# Subtraction = -2
# Multiplication = 168
# Division = 0.8571428571428571

# %%
n = int(input("Enter a number: "))
original = n
reverse = 0
while n > 0:
    d = n % 10
    reverse = reverse * 10 + d
    n = n // 10
if original == reverse:
    print("Palindrome Number")
else:
    print("Not a Palindrome Number")
# Out:
# Palindrome Number
