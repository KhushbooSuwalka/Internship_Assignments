# %%
x="string"
x=23+42j
print(type(x))
# Out:
# <class 'complex'>

# %%
price=75
print(f"The price is ${price:.2f}.")
# Out:
# The price is $75.00.

# %%
a="Hello"
b="World"
print(a+b)
# Out:
# HelloWorld

# %%
s="Hellooo"
print(s.lower())
# Out:
# hellooo

# %%
s="Heello"
print(s.replace("e","a"))
# Out:
# Haallo

# %%
s="Heello"
s.ljust(20,"*")
# Out:
# 'Heello**************'

# %%
s="    this is string"
print(s.strip())
# Out:
# this is string

# %%
s="    Heello    "
print(s.lstrip()) #removes leading whitespace(left side spaces)
# Out:
# Heello

# %%
s="   Helllo   "
#print(s.rstrip()) #removes trailing whitespace(right side spaces)
#Alternative method to remove left and right spaces
(s.lstrip()).rstrip()
# Out:
# 'Helllo'

# %%
l="Tisyn"
e="12345"
str="This is python"
encoding=str.maketrans(l,e)
print(str.translate(encoding))
# Out:
# 1h23 23 p4tho5

# %%
a="Hello !!!!"
b="World"
if (b not in a):
    print("Substring b not found in a")
# Out:
# Substring b not found in a

# %%
s="-"
seq=("a","b","c")
print(s.join(seq))
# Out:
# a-b-c

# %%
n1=int(input("Enter your number: "))
print("Your number is",n1)
print(type(n1))
# Out:
# Your number is 12
# <class 'int'>

# %%
n1=input("Enter your number: ")
print("Your number is",n1)
print(type(n1))
# Out:
# Your number is 12
# <class 'str'>

# %%
n1=input("Enter your name: ")
print("Hello",n1)
print(type(n1))
# Out:
# Hello Khushal
# <class 'str'>

# %%
a=10
b=10
print(id(a))
print(id(b))
# Out:
# 140710521062808
# 140710521062808

# %%
print("""Hey
This is a multi-line string
in Python
""")
# Out:
# Hey
# This is a multi-line string
# in Python

# %%
a="this is python"
print(a,type(a))
a=123
print(a,type(a))
a=True
print(a,type(a))
# Out:
# this is python <class 'str'>
# 123 <class 'int'>
# True <class 'bool'>

# %%
print("Heyyyyy its meeeeee")
# Out:
# Heyyyyy its meeeeee

# %%
print("HELLO WORLD")
print("Heyyyyy its meeeeee","My name is Khushbu",sep="---",end="!!!\n")
print("I like to code in Python")
# Out:
# HELLO WORLD
# Heyyyyy its meeeeee---My name is Khushbu!!!
# I like to code in Python

# %%
x=11
print("x is greater than 10") if x>10 else print("x is less than or equal to 10")
# Out:
# x is greater than 10

# %%
x=int(input("Enter a number: "))
for i in range(1,11):
    print(f"{x} x {i} = {x*i}")
# Out:
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
c="y"
while c!="x":
    c=input("Enter a character (enter 'x' to exit): ")

# %%
c="y"
while (True):
    c=input("Enter a character (enter 'x' to exit): ")
    if c=="x":
        break

# %%
for i in range(5,0,-1):
    for j in range(5):
        print(i,j,sep="---")
# Out:
# 5---0
# 5---1
# 5---2
# 5---3
# 5---4
# 4---0
# 4---1
# 4---2
# 4---3
# 4---4
# 3---0
# 3---1
# 3---2
# 3---3
# 3---4
# 2---0
# 2---1
# 2---2
# 2---3
# 2---4
# 1---0
# 1---1
# 1---2
# 1---3
# 1---4

# %%
str="Python is great"
print(str[0:8:3])
# Out:
# Ph
